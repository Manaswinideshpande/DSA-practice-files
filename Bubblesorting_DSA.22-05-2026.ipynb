# %%
# to print list1

list1 =[90,70,50,80,60,85]
import sys
def main():
    scores = list1
    length = len(scores)
    for i in range(0,length):
        print(scores[i],",",end ="")
if __name__ == "__main__" :
    main()
# Out:
# 90 ,70 ,50 ,80 ,60 ,85 ,

# %%
# Max value
import sys
def  max (arrays):
    length = len(arrays)
    for i in range(0,length-1):
        if arrays[ i] > arrays[ i + 1 ]:
            temp = arrays[ i]
            arrays[ i] = arrays[ i + 1 ]
            arrays[ i + 1 ] = temp
    maxValue = arrays[ length - 1 ]
    return maxValue
def main ():
    scores = [ 60 , 50 , 95 , 80 , 70 ]
    maxValue = max( scores)
    print ( "Max Value = " , maxValue)
if __name__ == "__main__" :
    main()
# Out:
# Max Value =  95

# %%
#Sorting
def sort(arrays):
    length =len(arrays)
    for i in range(0,length-1):
        for j in range(0,length-i-1):
            if arrays[j] > arrays[j+1]:
                flag = arrays[j]
                arrays[j] = arrays[j+1]
                arrays[j+1] =flag
def main():
    scores = [60,50,95,80,70]
    sort(scores)
    for score in scores:
        print(score,",",end ="")
if __name__ == "__main__":
    main()
# Out:
# 50 ,60 ,70 ,80 ,95 ,

# %%
# Min value
import sys
def min(arrays):
    min_value =0
    length =len(arrays)-1
    for i in range(0,length):
        if arrays[min_value] > arrays[i]:
            min_value = i
    return arrays[min_value]
def main():
    scores =[60,80,95,50,70]
    min_value = min(scores)
    print("Min value",min_value)
if __name__ =="__main__":
    main()
# Out:
# Min value 50

# %%
#Minimum value index
import sys
def min(arrays):
    min_value =0
    length =len(arrays)-1
    for i in range(0,length):
        if arrays[min_value] > arrays[i]:
            min_value = i
    return min_value
def main():
    scores =[60,80,95,50,70]
    min_value = min(scores)
    print("Min value",min_value)
if __name__ =="__main__":
    main()
# Out:
# Min value 3

# %%
#Minimum value index -Selection Sort(opposite to bubble sorting)
import sys
def sort(arrays):
    min_index =0
    length = len(arrays)-1
    for i in range(0,length):
        min_index =i
        min_value = arrays[min_index]
        for j in range(i,length):
            if min_value > arrays[j+1]:
                min_value =  [j+1]
                min_index = j+1
            if i!=min_index:
                temp = arrays[i]
                arrays[i] = arrays[min_index]
                arrays[min_index] = temp
def main():
    scores = [ 60 , 80 , 95 , 50 , 70 ]
    sort(scores)
    for score in scores:
        print(score,",",end ="")
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 23
#      21         print(score,",",end ="")
#      22 if __name__ == "__main__":
# ---> 23     main()
#
# Cell In[1], line 19, in main()
#      17 def main():
#      18     scores = [ 60 , 80 , 95 , 50 , 70 ]
# ---> 19     sort(scores)
#      20     for score in scores:
#      21         print(score,",",end ="")
#
# Cell In[1], line 10, in sort(arrays)
#       8 min_value = arrays[min_index]
#       9 for j in range(i,length):
# ---> 10     if min_value > arrays[j+1]:
#      11         min_value =  [j+1]
#      12         min_index = j+1
#
# TypeError: '>' not supported between instances of 'list' and 'int'

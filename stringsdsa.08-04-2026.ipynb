# %% [markdown]
# problem 1.
# There are n bulbs that are initially off.you first turn on all the bulbs.
# then you turn off every second bulb
# on the third round you toogle every third bulb (means if its on - off.if its off -on)
# for ith round, you toggle every ith bulb
# return the number of bulbs that are on after n rounds
#
# eg1.
# input: n = 3
# output =1
# explanation:
# at first the three  bulbs are [off,off,off]
# after the first round the three bulbs are [on,on,on]
# after the second round, the three bulbs are [on,off,on]
# after the third round the three  bulbs are[on, off,off]
# so you should return 1 because there is only one bulb is on
#
# eg2.
# input:n=0
# output:0
# eg3.
# input =1
# output=1

# %%
# method 1
n= int(input("value :"))
bulb = [0]*(n+1)
for i in range(1,n+1):
    for j in range(i,n+1,i):
        if bulb[j] ==0:
            bulb[j] =1
        else:
            bulb[j] =0
ans = 0
for i in range(1,n+1):
    if bulb[i] ==1:
        ans +=1
print(ans)
# Out:
# value : 3
# 1

# %%
# method 1
n= int(input("value :"))
bulb = [0]*(n+1)
for i in range(1,n+1):
    for j in range(i,n+1,i):
        if bulb[j] ==0:
            bulb[j] =1
        else:
            bulb[j] =0
ans = 0
for i in range(1,n+1):
    if bulb[i] ==1:
        ans +=1
print(ans)
# Out:
# value : 1
# 1

# %%
# method 1
n= int(input("value :"))
bulb = [0]*(n+1)
for i in range(1,n+1):
    for j in range(i,n+1,i):
        if bulb[j] ==0:
            bulb[j] =1
        else:
            bulb[j] =0
ans = 0
for i in range(1,n+1):
    if bulb[i] ==1:
        ans +=1
print(ans)
# Out:
# value : 0
# 0

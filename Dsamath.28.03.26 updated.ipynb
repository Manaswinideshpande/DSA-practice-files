# %% [markdown]
# ***Problem1***.Given a positive integer n,return the smallest positive integer that is a multiple of both 2 and n
#
# eg 1:
# input: n=5
# output:10
# explanation: the smallest  multiple of both 5 and 2 is 10
#
# Note:*for oddnum:- we do oddnum multiplication with 2 to get the smallest positive integer that is a multiple of both 2 and n
#
#
# eg 2:
# input: n=6
# output:6
# explanation: the smallest  multiple of both 6 and 2 is 6. note: the number is a multiple of itself
#
# Note: for even we consider evennumber (n) itself to get the smallest positive integer that is a multiple of both 2 and n

# %%
n =int(input("enter the value: "))
if n%2 == 0: # even number checking
    print(n)
else:
    print(n*2) # if  odd number multiplied by 2 gives even value
# Out:
# enter the value:  5
# 10

# %%
n =int(input("enter the value: "))
if n%2 == 0: # even number checking
    print(n)
else:
    print(n*2) # if  odd number multiplied by 2 gives even value
# Out:
# enter the value:  6
# 6

# %% [markdown]
# ***Problem2***. given an integer number n , return the difference between the product of its digits and sum of its digits
#
# eg1.
# input: n= 24
# output = 15
# explanation:
# products of digits = 2*3*4 =24
# sum of digits = 2+3+4 = 9
# Result = 24-9 = 15
#
#
# eg2.
# input: n= 4421
# output = 21
# explanation:
# products of digits = 4*4*2*1 =32
# sum of digits = 4+4+2+1 = 11
# Result = 32-11= 21
#
# constraints:
# 1<=n<=10^5

# %%
sum = 0
n = int(input('enter the value:' ))
productstore= 1
for i in str(n):
    productstore *= int(i)
    sum = sum + int(i)
    result = productstore-sum
print(result)
print(productstore)
print(sum)
# Out:
# enter the value: 4421
# 21
# 32
# 11

# %%
#method2
n = int(input('Enter value: '))
pro = 1
sum = 0
original_n = n  # optional, to keep original number

while n != 0:
    digit = n % 10
    sum += digit
    pro *= digit
    n = n // 10  # remove the last digit

print("Sum of digits:", sum)
print("Product of digits:", pro)
# Out:
# Enter value:  234
# Sum of digits: 9
# Product of digits: 24

# %% [markdown]
# ***problem3***.Given an array nums containing n distinct numbers in the range[0,n]  return the only number in the range that is missing from array
#
# eg1.
# input:nums=[3,0,1]
# output:2
# explanation:  n=3 since there are 3 numbers , so all numbers are in the range [0,3]. 2 is missing number in the  range since it does not appear in nums.
#
# eg2.
# input:nums=[0,1]
# output:2
# explanation:  n=2 since there are 2 numbers , so all numbers are in the range [0,2]. 2 is missing number in the  range since it does not appear in nums
#
# eg3.
# input:nums=[9,6,4,2,3,5,7,0,1]
# output:8
# explanation:  n=9 since there are 9 numbers , so all numbers are in the range [0,9]. 8 is missing number in the  range since it does not appear in nums
#
# constraints:
# n = nums,length
# 1<=n<=10base4
# 0<=nums[i]<=n
# all the numbers of nums are unique

# %%
n = list(map(int, input("Enter numbers separated by space: ").split()))
missing_value = []

for i in range(min(n), max(n)+1):
    if i not in n:
        missing_value.append(i)

print("Missing values:", missing_value)
# Out:
# Enter numbers separated by space:  9 6 4 2 3 5 7 0 1
# Missing values: [8]

# %%
n = list(map(int, input("Enter numbers separated by space: ").split()))
missing_value = []

for i in range(min(n), max(n)+1):
    if i not in n:
        missing_value.append(i)

print("Missing values:", missing_value)
# Out:
# Enter numbers separated by space:  3 0 1
# Missing values: [2]

# %%
n = list(map(int, input("Enter numbers separated by space: ").split()))
missing_value = []

for i in range(min(n), max(n)+1):
    if i not in n:
        missing_value.append(i)

print("Missing values:", missing_value)
# Out:
# Enter numbers separated by space:  0 1 3
# Missing values: [2]

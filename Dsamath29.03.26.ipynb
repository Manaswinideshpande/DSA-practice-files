# %% [markdown]
# ***Problem 1***. You are given a positive integer number consisting only of digits 6 and 9
# return the maximum number you can get by changing at most one digit
#
# eg1.
#
# input: num = 9669
#
# output:9969
# explanation:
# changing the first digit results in 6669
# changing the second digit results in 9969
# changing the third digit results in 9699
# changing the fourth digit results in 9666
# the maximum number is 9969
#
# eg2.
# input : num=9996
# output:9999
# explanation: changing the last digit 6 to 9 results in  the maximum numbet
#
# eg3.
# input:num = 9999
# output:9999
# explanation:it is better not to apply any change
#
# constraints:
# 1<=num<=10power4
# num consists of only 6 and 9 digits.

# %%
num = input("value: ")

# replace first '6' with '9' (if exists)
num = num.replace('6', '9', 1)

print(num)
# Out:
# value:  9669
# 9969

# %%
num = input("value: ")

# replace first '6' with '9' (if exists)
num = num.replace('6', '9', 1)

print(num)
# Out:
# value:  9996
# 9999

# %%
#method2:
n = input('value:' )
if '6' in n:
    n= n.replace('6', '9', 1)
elif '9' in n:
    n = n.replace('9', '6', 1)
print(n)
# Out:
# value: 9996
# 9999

# %%
#method3
n = input('value: ')
ans = ""
flag = 0

for i in n:
    if i == '6' and flag == 0:
        ans = ans + '9'
        flag = 1
    else:
        ans = ans + i   # keep original digit

print(ans)
# Out:
# value:  9669
# 9969

# %% [markdown]
# ***Problem2***:
#
# given two positive integers a and b,
# return  the number of common factors of a and b
# an integer x is a common factor of a and b if x divides both a and b
#
# eg1.
# input:a=12, b= 6
# output = 4
# explanation: the common factors of 12 and 6 are 1,2,3,6
#
# input:a=25,b=30
# output = 2
# explanation:The common factors  of 25 and 30 are 1,5
#
# constraints:
# 1<=a , b<=1000

# %%
a= int(input('value:'))
b= int(input('value:'))
count = 0

for i in range(1,min(a,b)+1): # min(a+b) a factor cannot be bigger than the smaller number,loop from 1 to the smaller number to check all possible common factors 
    if a%i ==0 and b%i ==0:  
        count +=1
       # print(i)
print(count)
# Out:
# value: 12
# value: 6
# 4

# %%
a= int(input('value:'))
b= int(input('value:'))
count = 0

for i in range(1,min(a,b)+1): # min(a+b) takes the smaller number,loop from 1 to the smaller number to check all possible common factors 
    if a%i ==0 and b%i ==0:  
        count +=1
       # print(i)
print(count)
# Out:
# value: 25
# value: 30
# 2

# %% [markdown]
# ***Problem3***: Count Even Digit Numbers
# 👉 Given an integer n, count how many numbers from 1 to n have an even number of digits.
#
# 🔎 Example:
# Input: n = 25
# Numbers: 1 to 25
# Even digit numbers → 10 to 25 (2-digit numbers)
# 👉 Output: 16

# %%
n = int(input('value: '))
count =0
for digit in range(1,n+1):
    if len(str(digit))%2 == 0: 
        count += 1
print(count)
# Out:
# value:  25
# 16

# %% [markdown]
# 🧩 ***Problem4***: Sum of Digits Until Single Digit (Digital Root)
#
# 👉 Given an integer n, keep summing its digits until you get a single digit.
#
# Examples:
# Input: n = 38
# → 3 + 8 = 11
# → 1 + 1 = 2
# 👉 Output: 2
#
# Input: n = 999
# → 9+9+9 = 27
# → 2+7 = 9
# 👉 Output: 9
#
# 🧠 Hint:
#
# 👉 Use loop + digit extraction OR string conversion
#
# 🎯 Constraint:
# 0 ≤ n ≤ 10^9

# %%
n = input("value:")

for i in range(10):
    if len(n) == 1:
        break
    s=0
    for j in n:
        s+=int(j)
    n = str(s)
print(n)
# Out:
# value: 999
# 9

# %%
n = input("value:")

for i in range(10):
    if len(n) == 1:
        break
    s=0
    for j in n:
        s+=int(j)
    n = str(s)
print(n)
# Out:
# value: 38
# 2
